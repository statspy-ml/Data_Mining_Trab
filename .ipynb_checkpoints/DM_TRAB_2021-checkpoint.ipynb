# %%
import pandas as pd
import numpy as np
import re
import sqlite3

# %%
conn = sqlite3.connect("tweets.sqlite")

# %%
df = pd.read_sql_query("SELECT * FROM Tweet", conn)

# %%
df
# Out:
#           id            tweet_id  \
# 0          1  858793053972307968
# 1          2  858793027871154180
# 2          3  858793021177040896
# 3          4  858793273757970433
# 4          5  858793272017387521
# ...      ...                 ...
# 42705  42706  861320837886038018
# 42706  42707  861320949060317184
# 42707  42708  861321047630643201
# 42708  42709  861321041393668096
# 42709  42710  861321102752198658
#
#                                                     text  sentiment
# 0      @caprichOreality Fica assim não miga &lt;3 Tud...          1
# 1      Amanhã é dia de dar um trato na palestra para ...          1
# 2      @thankovsky @patorebaichado eu também tenho :)...          1
# 3      @JoseAbrantes6 Prefiro amar o meu clube nas vi...          1
# 4      @Bel_Reedus Recomendamos que vá até uma loja C...          1
# ...                                                  ...        ...
# 42705  Pensa numa pessoa triste , eu tô dez vezes mai...          0
# ...
